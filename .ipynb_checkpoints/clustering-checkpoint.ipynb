# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('cosmo_graph1.csv')

# Preview the data
print(df.head())
# Out:
#             source           target  weight  distance
# 0  CASSLDSSGGNEQYF  CASSLDSSSGNTIYF   0.118         1
# 1  CASSLDSSGGNEQYF    CASIDSSGNTLYF   0.124         3
# 2  CASSLDSSGGNEQYF  CASSLVSSGANVLTF   0.151         2
# 3   CASSDSGEAGELFF   CASSSQGAAGELFF   0.147         3
# 4  CASSLELAAWETQYF  CASSVELAGTYEQYF   0.227         4

# %%
import networkx as nx

# Create a graph
G = nx.Graph()

# Add edges with attributes
for _, row in df.iterrows():
    G.add_edge(row['source'], row['target'], weight=row['weight'], distance=row['distance'])

# %% [markdown]
# ## Clustering Methods ##

# %% [markdown]
# ### Spectral Clustering ###

# %%
from sklearn.cluster import SpectralClustering
import numpy as np

# Create adjacency matrix
adj_matrix = nx.to_numpy_array(G, weight='weight')

# Apply Spectral Clustering
n_clusters = 5  # Specify the number of clusters
sc = SpectralClustering(n_clusters=n_clusters, affinity='precomputed')
labels = sc.fit_predict(adj_matrix)

# Assign clusters back to nodes
clusters = {node: labels[i] for i, node in enumerate(G.nodes())}
print(clusters)
# Out:
# {'CASSLDSSGGNEQYF': 2, 'CASSLDSSSGNTIYF': 2, 'CASIDSSGNTLYF': 2, 'CASSLVSSGANVLTF': 2, 'CASSDSGEAGELFF': 0, 'CASSSQGAAGELFF': 0, 'CASSLELAAWETQYF': 2, 'CASSVELAGTYEQYF': 2, 'CASSSRHEGEDTEAFF': 0, 'CASSRDLGRDTQYF': 0, 'CASSLIGVSSYNEQFF': 0, 'CASSITLSSYNEQFF': 0, 'CASSLAVLSSYNEQFF': 0, 'CASSVATSGGSQQFF': 4, 'CASSQAGQGNSPLHF': 4, 'CASSLKIGEQFF': 3, 'CASSLVGGEQYF': 1, 'CASSARTGELFF': 3, 'CASSPVTGGIYGYTF': 1, 'CASSPSTGTIYGYTF': 1, 'CASSYPGGGFYEQYF': 1, 'CASSWGQGSNYGYTF': 0, 'CSANDRTSGSNYNEQFF': 0, 'CASNGQGDTEAFF': 0, 'CASSFGQSSTYGYTF': 0, 'CASSLGQGLLYGYTF': 0, 'CASSQVLVGETQYF': 2, 'CASSLGALGETQYF': 2, 'CASSVLAGDTQYF': 2, 'CASSQTQLWETQYF': 2, 'CASSWVPPGQGRTGELFF': 3, 'CASSPAGQGGYEQYF': 3, 'CASSQGPQVRGADTQYF': 0, 'CASGGQGRAEQFF': 0, 'CASSDDRGPYEQYF': 1, 'CASSYDRGPREGYTF': 1, 'CASAQIGPYEQYF': 1, 'CASRIWDGGASTDTQYF': 4, 'CSVGGSGGADTQYF': 4, 'CASSYWDRTTSGNTIYF': 4, 'CASSIGQGKSSYEQYF': 4, 'CTCSAAPDWGASAETLYF': 4, 'CASSDAGGRNTLYF': 3, 'CASSQEGGGETQYF': 3, 'CASSPGGGMNTEAFF': 3, 'CASSLVGGRHGYTF': 3, 'CASSAGLDAEQYF': 0, 'CASSLGI
': 1, 'CASSQDRASGEYEQYF': 2, 'CASSQDLASGTYNEQFF': 2, 'CASSAGTSGEYEQYF': 2, 'CASSHGASTDTQYF': 0, 'CASTRESTDTQYF': 0, 'CASSIRSTDTQYF': 0, 'CAAGTRTDTQYF': 0, 'CASRGTGGGSGQPQHF': 0, 'CASSVRSTDTQYF': 0, 'CASSHWDRETSGNTIYF': 4, 'CASSSGQAYEQYF': 0, 'CASSPTSGIYEQYF': 1, 'CASSSPHRDSYSPLHF': 0, 'CAISDPRDSYEQYF': 0, 'CASSLREMGGKAEAFF': 3, 'CASSPRGRGGREDTQYF': 3, 'CASSLQRGRTDTQYF': 1, 'CASSLLTGGTDTQYF': 1, 'CAISAPRGERDEQYF': 1, 'CASSHLDRGKKDYEQYF': 1, 'CASSLGFLGPAAGNTIYF': 3, 'CASKVGAGGLYEQYF': 3, 'CASRVGTGNLYEQYF': 3, 'CASRPRRDNEQFF': 0, 'CASGLGGSNEQFF': 0, 'CSARGADTQYF': 2, 'CASSFGADTQYF': 2, 'CASSFFGAQQVDGYTF': 4, 'CASSFRALAADTQYF': 4, 'CATSATGLRNQPQHF': 4, 'CASSLYGAGNSPLHF': 4, 'CSVGGAYEQYF': 4, 'CASSNRGLGTDTQYF': 4, 'CASTNRQEGQETQYF': 1, 'CASMGRDINQPQHF': 1, 'CASSYASNQPQHF': 1, 'CASSLYSNQPQHF': 1, 'CAISTGDSNQPQHF': 1, 'CSARDLRLLANTGELFF': 1, 'CASSLRQALRNEQFF': 1, 'CASGLTGFMDEQYF': 2, 'CASRGLQGRIDYNEQFF': 2, 'CSVVQGAECTF': 2, 'CASSLAQGGETQYF': 2, 'CASSWGQGKSSYEQYF': 4, 'CASSIVERAEAFF': 1, 'CASSSIAGRGEKLFF': 1, 'CASSQDPGSSYNEQFF': 0, 'CASSSSGSSYNEQFF': 0, 'CASSLTGPGDQPQHF': 1, 'CASSLRGRGDQPQHF': 1, 'CAISESGTGFEQYF': 3, 'CASSEDGMNTEAFF': 3, 'CASSLYGNQPQHF': 1, 'CSAVGLAGVRSYEQYF': 2, 'CASGDFWGDTLYF': 0, 'CASGQGNFDIQYF': 0, 'CASSSRAAYEQYF': 0, 'CASSPSRVLYEQYF': 0, 'CASSIIPDMNTE ...

# %% [markdown]
# ### KMeans ###

# %%
from node2vec import Node2Vec
from sklearn.cluster import KMeans

# Generate embeddings using Node2Vec
node2vec = Node2Vec(G, dimensions=64, walk_length=30, num_walks=200, workers=4)
model = node2vec.fit(window=10, min_count=1, batch_words=4)

# Get embeddings for each node
embeddings = {node: model.wv[node] for node in G.nodes()}

# Convert embeddings to a matrix
X = np.array([embeddings[node] for node in G.nodes()])

# Apply KMeans clustering
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(X)

# Assign clusters back to nodes
clusters = {node: kmeans.labels_[i] for i, node in enumerate(G.nodes())}
print(clusters)

# %% [markdown]
# ## Visualize clustering ##

# %%
import matplotlib.pyplot as plt

# Color nodes based on clusters
colors = [labels[i] for i, node in enumerate(G.nodes())]
nx.draw(G, with_labels=True, node_color=colors, cmap=plt.cm.tab10)
plt.show()
